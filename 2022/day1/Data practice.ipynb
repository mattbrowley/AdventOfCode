# %%
myString = """This is a 
multi line string
It has
many lines"""
lines = myString.splitlines()
print(myString)
print(lines)
# Out:
# This is a
# multi line string
# It has
# many lines
# ['This is a ', 'multi line string', 'It has', 'many lines']

# %%
"12" + "34"
# Out:
# '1234'

# %%
print(type("1234"))
print(type(int("1234")))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print("12" + "34")
print(int("12") + int("34"))
# Out:
# 1234
# 46

# %%
max([3,7,1,0,9,2])
# Out:
# 9

# %%
lines[:3]
# Out:
# ['This is a ', 'multi line string', 'It has']
